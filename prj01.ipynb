# %%
import math
def prime(n):#definite what is prime
    count=0
    for  i in range(2,int(math.sqrt(n))+1):
        if n%i==0:
            count=1
        i+=1
    if count==1:
        return None
    else:
        return True

# %%
a=[]

# %%
b = 0
for j in range(1000,1000000):# We find the twinprime in the known prime for range 1000~1000000
    if prime(j)==True:
        a.append(j)

for k in range(len(a)-1):#we find the twins near the known primes
    if a[k]+2==a[k+1]:
        print (a[k],a[k+1])
        b +=1
# Out:
# 1019 1021
# 1031 1033
# 1049 1051
# 1061 1063
# 1091 1093
# 1151 1153
# 1229 1231
# 1277 1279
# 1289 1291
# 1301 1303
# 1319 1321
# 1427 1429
# 1451 1453
# 1481 1483
# 1487 1489
# 1607 1609
# 1619 1621
# 1667 1669
# 1697 1699
# 1721 1723
# 1787 1789
# 1871 1873
# 1877 1879
# 1931 1933
# 1949 1951
# 1997 1999
# 2027 2029
# 2081 2083
# 2087 2089
# 2111 2113
# 2129 2131
# 2141 2143
# 2237 2239
# 2267 2269
# 2309 2311
# 2339 2341
# 2381 2383
# 2549 2551
# 2591 2593
# 2657 2659
# 2687 2689
# 2711 2713
# 2729 2731
# 2789 2791
# 2801 2803
# 2969 2971
# 2999 3001
# 3119 3121
# 3167 3169
# 3251 3253
# 3257 3259
# 3299 3301
# 3329 3331
# 3359 3361
# 3371 3373
# 3389 3391
# 3461 3463
# 3467 3469
# 3527 3529
# 3539 3541
# 3557 3559
# 3581 3583
# 3671 3673
# 3767 3769
# 3821 3823
# 3851 3853
# 3917 3919
# 3929 3931
# 4001 4003
# 4019 4021
# 4049 4051
# 4091 4093
# 4127 4129
# 4157 4159
# 4217 4219
# 4229 4231
# 4241 4243
# 4259 4261
# 4271 4273
# 4337 4339
# 4421 4423
# 4481 4483
# 4517 4519
# ...

# %%
print("The largest twinprime in range 1000~1000000:",a[k-2],a[k-1])# after run k will be added 1,so we get the k-2 and k-1 is the largest twinsprime
# Out:
# The largest twinprime in range 1000~1000000: 999959 999961

# %%
print("The number of twinprime in range 1000~1000000:",b)
# Out:
# The number of twinprime in range 1000~1000000: 8134

# %% [markdown]
# https://github.com/yumengsun3/MA6628/blob/master/prj01
